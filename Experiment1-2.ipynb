# %% [markdown]
# # Load Product Data

# %%
import pandas as pd
import numpy as np

product_info = pd.read_csv("product_info.csv")
product_info.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8494 entries, 0 to 8493
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          8494 non-null   object
#  1   product_name        8494 non-null   object
#  2   brand_id            8494 non-null   int64
#  3   brand_name          8494 non-null   object
#  4   loves_count         8494 non-null   int64
#  5   rating              8216 non-null   float64
#  6   reviews             8216 non-null   float64
#  7   size                6863 non-null   object
#  8   variation_type      7050 non-null   object
#  9   variation_value     6896 non-null   object
#  10  variation_desc      1250 non-null   object
#  11  ingredients         7549 non-null   object
#  12  price_usd           8494 non-null   float64
#  13  value_price_usd     451 non-null    float64
#  14  sale_price_usd      270 non-null    float64
#  15  limited_edition     8494 non-null   int64
#  16  new                 8494 non-null   int64
#  17  online_only         8494 non-null   int64
#  18  out_of_stock        8494 non-null   int64
#  19  sephora_exclusive   8494 non-null   int64
#  20  highlights          6287 non-null   object
#  21  primary_category    8494 non-null   object
#  22  secondary_category  8486 non-null   object
#  23  tertiary_category   7504 non-null   object
#  24  child_count         8494 non-null   int64
#  25  child_max_price     2754 non-null   float64
#  26  child_min_price     2754 non-null   float64
# dtypes: float64(7), int64(8), object(12)
# memory usage: 1.7+ MB

# %%
num_missing = product_info.isna().sum()
num_missing
# Out:
# product_id               0
# product_name             0
# brand_id                 0
# brand_name               0
# loves_count              0
# rating                 278
# reviews                278
# size                  1631
# variation_type        1444
# variation_value       1598
# variation_desc        7244
# ingredients            945
# price_usd                0
# value_price_usd       8043
# sale_price_usd        8224
# limited_edition          0
# new                      0
# online_only              0
# out_of_stock             0
# sephora_exclusive        0
# highlights            2207
# primary_category         0
# secondary_category       8
# tertiary_category      990
# child_count              0
# child_max_price       5740
# child_min_price       5740
# dtype: int64

# %% [markdown]
# # Content-based (skincare + makeup only, remove products with no ingredients) | Experiment 1

# %%
products = pd.DataFrame(product_info, columns=['product_id','product_name','ingredients','highlights', 'primary_category'])
products.head(5)
products.shape
# Out:
# (8494, 5)

# %%
product_info.shape
# Out:
# (8494, 27)

# %%
products = products[products['primary_category'].isin(['Skincare', 'Makeup'])]

# %%
products = products.dropna(subset='ingredients')
products.shape
# Out:
# (4319, 5)

# %%
products = products.reset_index(drop=True)

indices = pd.Series(products.index, index=products['product_name'])

products
# Out:
#      product_id                                       product_name  \
# 0       P398965                               Rose Lip Conditioner
# 1       P439055               GENIUS Sleeping Collagen Moisturizer
# 2       P421277                       GENIUS Liquid Collagen Serum
# 3       P467602            Triple Algae Eye Renewal Balm Eye Cream
# 4       P432045               GENIUS Liquid Collagen Lip Treatment
# ...         ...                                                ...
# 4314    P474604   NU TONE CORRECTOR Color Corrector with Vitamin E
# 4315    P483501               Mini Rouge Pur Couture Exclusive Set
# 4316    P467660             Mascara Volume Effet Faux Cils Radical
# 4317    P467659                   Couture Clutch Eyeshadow Palette
# 4318    P505461  Candy Glaze Lip Gloss Stick Duo with Hyaluroni...
#
#                                             ingredients  \
# 0     ['Polybutene; Hydrogenated Polyisobutene; Dext...
# 1     ['Collagen (Vegan)*, Water (Aqua, Eau), Ethylh...
# 2     ['Collagen (Vegan)*, Water (Aqua, Eau), Propan...
# 3     ['Aqua (Water/Eau), Stearic Acid, Isopropyl Is...
# 4     ['Collagen (Vegan)*, Water (Aqua, Eau), Glycer...
# ...                                                 ...
# 4314  ['Aqua/Water/Eau, Glycerin, Alcohol Denat., Bu...
# 4315  ['Pentaerythrityl Isostearate/Caprate/Caprylat...
# 4316  ['Aqua/Water, Paraffin, Stearic Acid, Copernic...
# 4317  ['Talc, Synthetic Fluorphlogopite, Triethylhex...
# 4318  ['Diisostearyl Malate, Bis-Behenyl/Isostearyl/...
#
#                                              highlights primary_category
# 0                    ['Hydrating', 'Good for: Dryness']           Makeup
# 1     ['Vegan', 'Good for: Loss of firmness', 'Colla...         Skincare
# 2     ['Vegan', 'Good for: Loss of firmness', 'Colla...         Skincare
# 3                                                   NaN         Skincare
# 4     ['Vegan', 'Good for: Loss of firmness', 'Plump...         Skincare
# ...                                                 ...              ...
# 4314  ['Natural Finish', 'Without Mineral Oil', 'Wit...           Makeup
# 4315                      ['Hydrating', 'Satin Finish']           Makeup
# 4316                                                NaN           Makeup
# 4317                                                NaN           Makeup
# 4318  ['Hyaluronic Acid', 'High Shine Finish', 'Plum...           Makeup
#
# [4319 rows x 5 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

texts = products.ingredients.values

tfidf_matrix = vectorizer.fit_transform(texts)

tfidf_matrix.shape
# Out:
# (4319, 7102)

# %%
from sklearn.metrics.pairwise import linear_kernel

cosine_similarity = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
def get_recommendations(product_name, cosine_sim=cosine_similarity):
    idx = indices[product_name]

    sim_scores = list(enumerate(cosine_similarity[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:6]

    product_indices = [i[0] for i in sim_scores]

    return products['product_name'].iloc[product_indices]

# %%
get_recommendations('GENIUS Sleeping Collagen Moisturizer', cosine_similarity)
# Out:
# 2             GENIUS Liquid Collagen Serum
# 26             Mini GENIUS Liquid Collagen
# 9                       10 Day Results Kit
# 4     GENIUS Liquid Collagen Lip Treatment
# 29                          Plump Pout Duo
# Name: product_name, dtype: object

# %% [markdown]
# # Collaborative Filtering (SVD) | Experiment 2

# %% [markdown]
# # Load Data

# %%
reviews = pd.read_csv("reviews_0-250.csv")
reviews.info()
# Out:
# <ipython-input-13-0ff548df0407>:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   reviews = pd.read_csv("reviews_0-250.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253832 entries, 0 to 253831
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                253832 non-null  int64
#  1   author_id                 253832 non-null  object
#  2   rating                    253832 non-null  int64
#  3   is_recommended            195179 non-null  float64
#  4   helpfulness               112626 non-null  float64
#  5   total_feedback_count      253832 non-null  int64
#  6   total_neg_feedback_count  253832 non-null  int64
#  7   total_pos_feedback_count  253832 non-null  int64
#  8   submission_time           253832 non-null  object
#  9   review_text               253311 non-null  object
#  10  review_title              184221 non-null  object
#  11  skin_tone                 202661 non-null  object
#  12  eye_color                 185889 non-null  object
#  13  skin_type                 219592 non-null  object
#  14  hair_color                185930 non-null  object
#  15  product_id                253831 non-null  object
#  16  product_name              253831 non-null  object
#  17  brand_name                253831 non-null  object
#  18  price_usd                 253831 non-null  float64
# dtypes: float64(3), int64(5), object(11)
# memory usage: 36.8+ MB

# %% [markdown]
# # Data Preprocessing

# %%
columns_to_drop = ['Unnamed: 0', 'total_feedback_count', 'total_neg_feedback_count', 'total_pos_feedback_count', 'submission_time', 'review_title', 'is_recommended', 'product_name', 'brand_name', 'price_usd']
reviews.drop(columns=columns_to_drop, inplace=True)

# %%
product_info = product_info[product_info['primary_category'].isin(['Skincare', 'Makeup'])]

product_info = product_info.dropna(subset=['reviews','rating'])

product_stats = reviews.groupby(['product_id'])['product_id'].count().reset_index(name='counts')

product_stats.sort_values('counts', ascending=False)

cutoff = product_stats['counts'].quantile(0.1)

filtered_products = product_stats.loc[product_stats['counts'] > cutoff]

products_set = filtered_products['product_id'].squeeze()

products_subset = product_info.loc[product_info['product_id'].isin(products_set)]

# %%
product_info.shape
product_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4679 entries, 65 to 8489
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          4679 non-null   object
#  1   product_name        4679 non-null   object
#  2   brand_id            4679 non-null   int64
#  3   brand_name          4679 non-null   object
#  4   loves_count         4679 non-null   int64
#  5   rating              4679 non-null   float64
#  6   reviews             4679 non-null   float64
#  7   size                3669 non-null   object
#  8   variation_type      3844 non-null   object
#  9   variation_value     3749 non-null   object
#  10  variation_desc      1189 non-null   object
#  11  ingredients         4223 non-null   object
#  12  price_usd           4679 non-null   float64
#  13  value_price_usd     229 non-null    float64
#  14  sale_price_usd      184 non-null    float64
#  15  limited_edition     4679 non-null   int64
#  16  new                 4679 non-null   int64
#  17  online_only         4679 non-null   int64
#  18  out_of_stock        4679 non-null   int64
#  19  sephora_exclusive   4679 non-null   int64
#  20  highlights          3538 non-null   object
#  21  primary_category    4679 non-null   object
#  22  secondary_category  4679 non-null   object
#  23  tertiary_category   4185 non-null   object
#  24  child_count         4679 non-null   int64
#  25  child_max_price     1688 non-null   float64
#  26  child_min_price     1688 non-null   float64
# dtypes: float64(7), int64(8), object(12)
# memory usage: 1023.5+ KB

# %%
columns_to_drop = ['variation_type', 'variation_value', 'variation_desc', 'price_usd', 'value_price_usd', 'sale_price_usd', 'limited_edition',
                   'new', 'online_only', 'out_of_stock', 'sephora_exclusive', 'child_count', 'child_max_price', 'child_min_price', 'secondary_category', 'tertiary_category']
product_info.drop(columns=columns_to_drop, inplace=True)

# %%
author_stats = reviews.groupby(['author_id'])['author_id'].count().reset_index(name='counts')

author_stats.sort_values('counts', ascending=False)

cutoff= author_stats['counts'].quantile(0.99)

filtered_authors = author_stats.loc[author_stats['counts'] > cutoff]

authors = filtered_authors['author_id'].squeeze()

reviews_subset = reviews.loc[reviews['author_id'].isin(authors)]

# %%
reviews_subset
# Out:
#           author_id  rating  helpfulness  \
# 747      5086845963       4     0.960784
# 748      5086845963       5     1.000000
# 877     22934451719       5     1.000000
# 878     22934451719       5     0.666667
# 996      5086845963       4     1.000000
# ...             ...     ...          ...
# 251947   1288462295       5          NaN
# 252062   1930716686       5          NaN
# 252367   5826279851       5          NaN
# 252395   1378522783       4          NaN
# 253517   2776710623       3     1.000000
#
#                                               review_text    skin_tone  \
# 747     Pumpkin spice smells okay. It’s a true pumpkin...       medium
# 748     Peppermint is a re-release from last year and ...  lightMedium
# 877     MY FAVORITE LIP SLEEPING MASK. It feels so goo...       medium
# 878     MY FAVORITE LIP SLEEPING MASK. It feels so goo...       medium
# 996     Focusing this review on the scent since the fo...  lightMedium
# ...                                                   ...          ...
# 251947  I got this as a sample & it is phenomenal...I ...  lightMedium
# 252062  Makes eye area very smooth.  Has perfect consi...        light
# 252367  This is the perfect consistency: not too heavy...        light
# 252395  Excited to receive this in my Play box! I love...         fair
# 253517  I received a free sample of this product - I w...    mediumTan
#
#        eye_color    skin_type hair_color product_id
# 747        brown  combination      black    P420652
# 748        brown  combination      black    P420652
# 877        brown         oily      black    P420652
# 878        brown         oily      black    P420652
# 996        brown  combination      black    P420652
# ...          ...          ...        ...        ...
# 251947      blue  combination        red    P422905
# 252062     brown          dry      brown    P422905
# 252367     brown       normal      brown    P422905
# 252395     green         oily     blonde    P422905
# 253517     brown  combination      black    P430337
#
# [9350 rows x 9 columns]

# %%
reviews.shape
# Out:
# (253832, 9)

# %%
reviews_subset.shape
# Out:
# (9350, 9)

# %%
reviews_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9350 entries, 747 to 253517
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   author_id    9350 non-null   object
#  1   rating       9350 non-null   int64
#  2   helpfulness  4773 non-null   float64
#  3   review_text  9343 non-null   object
#  4   skin_tone    8296 non-null   object
#  5   eye_color    8081 non-null   object
#  6   skin_type    8722 non-null   object
#  7   hair_color   8055 non-null   object
#  8   product_id   9350 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 730.5+ KB

# %%
reviews_subset = reviews_subset.dropna(subset=['skin_tone', 'eye_color', 'skin_type', 'hair_color'])
reviews_subset['user_characteristics'] = reviews_subset.apply(
    lambda row: [
        f'{row["skin_tone"].capitalize()} Skintone',
        f'{row["eye_color"].capitalize()} Eyes',
        f'{row["skin_type"].capitalize()} Skintype',
        f'{row["hair_color"].capitalize()} Hair'
    ], axis=1
)
# Out:
# <ipython-input-23-94d9703c69ba>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_subset['user_characteristics'] = reviews_subset.apply(

# %%
reviews_subset.shape
reviews_subset
# Out:
#           author_id  rating  helpfulness  \
# 747      5086845963       4     0.960784
# 748      5086845963       5     1.000000
# 877     22934451719       5     1.000000
# 878     22934451719       5     0.666667
# 996      5086845963       4     1.000000
# ...             ...     ...          ...
# 251947   1288462295       5          NaN
# 252062   1930716686       5          NaN
# 252367   5826279851       5          NaN
# 252395   1378522783       4          NaN
# 253517   2776710623       3     1.000000
#
#                                               review_text    skin_tone  \
# 747     Pumpkin spice smells okay. It’s a true pumpkin...       medium
# 748     Peppermint is a re-release from last year and ...  lightMedium
# 877     MY FAVORITE LIP SLEEPING MASK. It feels so goo...       medium
# 878     MY FAVORITE LIP SLEEPING MASK. It feels so goo...       medium
# 996     Focusing this review on the scent since the fo...  lightMedium
# ...                                                   ...          ...
# 251947  I got this as a sample & it is phenomenal...I ...  lightMedium
# 252062  Makes eye area very smooth.  Has perfect consi...        light
# 252367  This is the perfect consistency: not too heavy...        light
# 252395  Excited to receive this in my Play box! I love...         fair
# 253517  I received a free sample of this product - I w...    mediumTan
#
#        eye_color    skin_type hair_color product_id  \
# 747        brown  combination      black    P420652
# 748        brown  combination      black    P420652
# 877        brown         oily      black    P420652
# 878        brown         oily      black    P420652
# 996        brown  combination      black    P420652
# ...          ...          ...        ...        ...
# 251947      blue  combination        red    P422905
# 252062     brown          dry      brown    P422905
# 252367     brown       normal      brown    P422905
# 252395     green         oily     blonde    P422905
# 253517     brown  combination      black    P430337
#
#                                      user_characteristics
# 747     [Medium Skintone, Brown Eyes, Combination Skin...
# 748     [Lightmedium Skintone, Brown Eyes, Combination...
# 877     [Medium Skintone, Brown Eyes, Oily Skintype, B...
# 878     [Medium Skintone, Brown Eyes, Oily Skintype, B...
# 996     [Lightmedium Skintone, Brown Eyes, Combination...
# ...                                                   ...
# 251947  [Lightmedium Skintone, Blue Eyes, Combination ...
# 252062  [Light Skintone, Brown Eyes, Dry Skintype, Bro...
# 252367  [Light Skintone, Brown Eyes, Normal Skintype, ...
# 252395  [Fair Skintone, Green Eyes, Oily Skintype, Blo...
# 253517  [Mediumtan Skintone, Brown Eyes, Combination S...
#
# [7915 rows x 10 columns]

# %% [markdown]
# # Combining 2 data

# %%
result = product_info.merge(reviews_subset,  how='inner', on='product_id')

# %%
result.shape
# Out:
# (7915, 20)

# %%
result = result.reset_index(drop=True)

# %% [markdown]
# # Calculate Cosine Similarity between users

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

result['user_characteristics_str'] = result['user_characteristics'].apply(lambda x: ', '.join(x))

texts = result.user_characteristics_str.values

vectorizer = TfidfVectorizer(max_features=100)

tfidf_matrix = vectorizer.fit_transform(texts)

user_sim_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %% [markdown]
# # Calculate Implicit Rating

# %%
from textblob import TextBlob

def get_sentiment_score(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity  # Returns a score between -1 and 1

result['review_text'] = result['review_text'].astype(str).fillna('')

result['sentiment_score'] = result['review_text'].apply(get_sentiment_score)

# %%
import numpy as np

def sentiment_to_rating(sentiment_score):
    return np.interp(sentiment_score, [-1, 1], [1, 5])

result['implicit_rating'] = result['sentiment_score'].apply(sentiment_to_rating)

# %%
result.info()
result
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7915 entries, 0 to 7914
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   product_id                7915 non-null   object
#  1   product_name              7915 non-null   object
#  2   brand_id                  7915 non-null   int64
#  3   brand_name                7915 non-null   object
#  4   loves_count               7915 non-null   int64
#  5   rating_x                  7915 non-null   float64
#  6   reviews                   7915 non-null   float64
#  7   size                      7780 non-null   object
#  8   ingredients               7914 non-null   object
#  9   highlights                7641 non-null   object
#  10  primary_category          7915 non-null   object
#  11  author_id                 7915 non-null   object
#  12  rating_y                  7915 non-null   int64
#  13  helpfulness               4063 non-null   float64
#  14  review_text               7915 non-null   object
#  15  skin_tone                 7915 non-null   object
#  16  eye_color                 7915 non-null   object
#  17  skin_type                 7915 non-null   object
#  18  hair_color                7915 non-null   object
#  19  user_characteristics      7915 non-null   object
#  20  user_characteristics_str  7915 non-null   object
#  21  sentiment_score           7915 non-null   float64
#  22  implicit_rating           7915 non-null   float64
# dtypes: float64(5), int64(3), object(15)
# memory usage: 1.4+ MB
#      product_id                                       product_name  brand_id  \
# 0       P460779  Skinlongevity Long Life Herb Anti-Aging Face S...      5737
# 1       P460779  Skinlongevity Long Life Herb Anti-Aging Face S...      5737
# 2       P460779  Skinlongevity Long Life Herb Anti-Aging Face S...      5737
# 3       P460779  Skinlongevity Long Life Herb Anti-Aging Face S...      5737
# 4       P460779  Skinlongevity Long Life Herb Anti-Aging Face S...      5737
# ...         ...                                                ...       ...
# 7910    P441644                Mini Superfood Antioxidant Cleanser      6169
# 7911    P441644                Mini Superfood Antioxidant Cleanser      6169
# 7912    P441644                Mini Superfood Antioxidant Cleanser      6169
# 7913    P441644                Mini Superfood Antioxidant Cleanser      6169
# 7914    P441644                Mini Superfood Antioxidant Cleanser      6169
#
#                brand_name  loves_count  rating_x  reviews           size  \
# 0            bareMinerals         7614    4.4339   3727.0  1.7 oz/ 50 mL
# 1            bareMinerals         7614    4.4339   3727.0  1.7 oz/ 50 mL
# 2            bareMinerals         7614    4.4339   3727.0  1.7 oz/ 50 mL
# 3            bareMinerals         7614    4.4339   3727.0  1.7 oz/ 50 mL
# 4            bareMinerals         7614    4.4339   3727.0  1.7 oz/ 50 mL
# ...                   ...          ...       ...      ...            ...
# 7910  Youth To The People       121678    4.2121   5841.0    2 oz/ 59 mL
# 7911  Youth To The People       121678    4.2121   5841.0    2 oz/ 59 mL
# 7912  Youth To The People       121678    4.2121   5841.0    2 oz/ 59 mL
# 7913  Youth To The People       121678    4.2121   5841.0    2 oz/ 59 mL
# 7914  Youth To The People       121678    4.2121   5841.0    2 oz/ 59 mL
#
#                                             ingredients  \
# 0     ['Water (Aqua/Eau), Propanediol, Niacinamide, ...
# 1     ['Water (Aqua/Eau), Propanediol, Niacinamide, ...
# 2     ['Water (Aqua/Eau), Propanediol, Niacinamide, ...
# 3     ['Water (Aqua/Eau), Propanediol, Niacinamide, ...
# 4     ['Water (Aqua/Eau), Propanediol, Niacinamide, ...
# ...                                                 ...
# 7910  ['Water/Aqua/Eau, Cocamidopropyl Hydroxysultai...
# 7911  ['Water/Aqua/Eau, Cocamidopropyl Hydroxysultai...
# 7912  ['Water/Aqua/Eau, Cocamidopropyl Hydroxysultai...
# 7913  ['Water/Aqua/Eau, Cocamidopropyl Hydroxysultai...
# 7914  ['Water/Aqua/Eau, Cocamidopropyl Hydroxysultai...
#
#                                              highlights  ... helpfulness  \
# 0     ['Vegan', 'Good for: Dullness/Uneven Texture',...  ...         1.0
# 1     ['Vegan', 'Good for: Dullness/Uneven Texture',...  ...         1.0
# 2     ['Vegan', 'Good for: Dullness/Uneven Texture',...  ...         NaN
# 3     ['Vegan', 'Good for: Dullness/Uneven Texture',...  ...         NaN
# 4     ['Vegan', 'Good for: Dullness/Uneven Texture',...  ...         NaN
# ...                                                 ...  ...         ...
# 7910  ['Refill Available', 'Community Favorite', 'Go...  ...         NaN
# 7911  ['Refill Available', 'Community Favorite', 'Go...  ...         NaN
# 7912  ['Refill Available', 'Community Favorite', 'Go...  ...         NaN
# 7913  ['Refill Available', 'Community Favorite', 'Go...  ...         NaN
# 7914  ['Refill Available', 'Community Favorite', 'Go...  ...         NaN
#
#                                             review_text  skin_tone  eye_color  \
# 0     Love this serum-it’s lightweight and really wo...       fair      green
# 1     Received a sample packet and I am currently or...      light      green
# 2     I’m really surprised at this! I have very dry ...  fairLight      brown
# 3     I love this serum. My skin has been a little s...        tan      brown
# 4     I recently received this to try it out and it ...      light      brown
# ...                                                 ...        ...        ...
# 7910  Honestly, it took a few weeks of using this cl...       fair      brown
# 7911  I initially got this brand in a play box and I...       fair       blue
# 7912  Smells nice. Looks cute. I don’t find that it ...      light      brown
# 7913  I got a decent sample size of this. It made my...  mediumTan      hazel
# 7914  Cleanses well, isn’t sticky or greasy or dryin...  fairLight       blue
#
#         skin_type hair_color  \
# 0     combination     blonde
# 1     combination     blonde
# 2             dry     blonde
# 3     combination      black
# 4     combination      brown
# ...           ...        ...
# 7910  combination      brown
# 7911         oily      brown
# 7912  combination     auburn
# 7913          dry      brown
# 7914          dry      brown
#
#                                    user_characteristics  \
# 0     [Fair Skintone, Green Eyes, Combination Skinty...
# 1     [Light Skintone, Green Eyes, Combination Skint...
# 2     [Fairlight Skintone, Brown Eyes, Dry Skintype,...
# 3     [Tan Skintone, Brown Eyes, Combination Skintyp...
# 4     [Light Skintone, Brown Eyes, Combination Skint...
# ...                                                 ...
# 7910  [Fair Skintone, Brown Eyes, Combination Skinty...
# 7911  [Fair Skintone, Blue Eyes, Oily Skintype, Brow...
# 7912  [Light Skintone, Brown Eyes, Combination Skint...
# 7913  [Mediumtan Skintone, Hazel Eyes, Dry Skintype,...
# 7914  [Fairlight Skintone, Blue Eyes, Dry Skintype, ...
#
#                                user_characteristics_str sentiment_score  \
# 0     Fair Skintone, Green Eyes, Combination Skintyp...        0.350000
# 1     Light Skintone, Green Eyes, Combination Skinty...        0.216667
# 2     Fairlight Skintone, Brown Eyes, Dry Skintype, ...       -0.043905
# 3     Tan Skintone, Brown Eyes, Combination Skintype...        0.022500
# 4     Light Skintone, Brown Eyes, Combination Skinty...        0.306548
# ...                                                 ...             ...
# 7910  Fair Skintone, Brown Eyes, Combination Skintyp...        0.227629
# 7911  Fair Skintone, Blue Eyes, Oily Skintype, Brown...        0.275000
# 7912  Light Skintone, Brown Eyes, Combination Skinty...        0.413333
# 7913  Mediumtan Skintone, Hazel Eyes, Dry Skintype, ...        0.266970
# 7914  Fairlight Skintone, Blue Eyes, Dry Skintype, B...        0.258333
#
#      implicit_rating
# 0           3.700000
# 1           3.433333
# 2           2.912189
# 3           3.045000
# 4           3.613095
# ...              ...
# 7910        3.455258
# 7911        3.550000
# 7912        3.826667
# 7913        3.533939
# 7914        3.516667
#
# [7915 rows x 23 columns]

# %% [markdown]
# # SVD

# %%
# !pip install surprise
# Out:
# Collecting surprise
#   Downloading surprise-0.1-py2.py3-none-any.whl.metadata (327 bytes)
# Collecting scikit-surprise (from surprise)
#   Downloading scikit_surprise-1.1.4.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 8.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.13.1)
# Downloading surprise-0.1-py2.py3-none-any.whl (1.8 kB)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (pyproject.toml) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp310-cp310-linux_x86_64.whl size=2357282 sha256=ac94d94db2fedf79caa6459652980f2477143420ba796e0760c1888a52be1d11
#   Stored in directory: /root/.cache/pip/wheels/4b/3f/df/6acbf0a40397d9bf3ff97f582cc22fb9ce66adde75bc71fd54
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise, surprise
# Successfully installed scikit-surprise-1.1.4 surprise-0.1

# %%
from surprise import Reader, Dataset, SVD, accuracy
from surprise.model_selection import train_test_split

reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(result[['author_id', 'product_id', 'rating_y']], reader)

trainset = data.build_full_trainset()

algo = SVD()

algo.fit(trainset)

# %%
testset = trainset.build_anti_testset()

predictions = algo.test(testset)

# %%
mse = accuracy.mse(predictions)
rmse = accuracy.rmse(predictions)
# Out:
# MSE: 0.1360
# RMSE: 0.3688

# %%
pred = pd.DataFrame(predictions)

# %%
def get_recommendations(user_id, pred):
    pred_subset = pred.loc[pred['uid'] == user_id]

    pred_subset.sort_values(by=['est'],ascending = False)

    product_list = pred_subset.head(5)['iid'].to_list()

    recommendations = product_info.loc[product_info['product_id'].isin(product_list)]

    return recommendations['product_name']

# %%
get_recommendations('2660223134', pred)
